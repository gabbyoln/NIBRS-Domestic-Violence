# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Look a bit at the administrative level

# %%
folder = "TX-2019/TX/"
agencies = pd.read_csv(folder + "agencies.csv")
agencies.columns
# Out:
# Index(['YEARLY_AGENCY_ID', 'AGENCY_ID', 'DATA_YEAR', 'ORI', 'LEGACY_ORI',
#        'COVERED_BY_LEGACY_ORI', 'DIRECT_CONTRIBUTOR_FLAG', 'DORMANT_FLAG',
#        'DORMANT_YEAR', 'REPORTING_TYPE', 'UCR_AGENCY_NAME', 'NCIC_AGENCY_NAME',
#        'PUB_AGENCY_NAME', 'PUB_AGENCY_UNIT', 'AGENCY_STATUS', 'STATE_ID',
#        'STATE_NAME', 'STATE_ABBR', 'STATE_POSTAL_ABBR', 'DIVISION_CODE',
#        'DIVISION_NAME', 'REGION_CODE', 'REGION_NAME', 'REGION_DESC',
#        'AGENCY_TYPE_NAME', 'POPULATION', 'SUBMITTING_AGENCY_ID', 'SAI',
#        'SUBMITTING_AGENCY_NAME', 'SUBURBAN_AREA_FLAG', 'POPULATION_GROUP_ID',
#        'POPULATION_GROUP_CODE', 'POPULATION_GROUP_DESC',
#        'PARENT_POP_GROUP_CODE', 'PARENT_POP_GROUP_DESC', 'MIP_FLAG',
#        'POP_SORT_ORDER', 'SUMMARY_RAPE_DEF', 'PE_REPORTED_FLAG',
#        'MALE_OFFICER', 'MALE_CIVILIAN', 'PED.MALE_OFFICER+PED.MALE_CIVILIAN',
#        'FEMALE_OFFICER', 'FEMALE_CIVILIAN',
#        'PED.FEMALE_CIVILIAN+PED.FEMALE_OFFICER', '0', '0.1', 'NIBRS_CERT_DATE',
#        'NIBRS_START_DATE', 'NIBRS_LEOKA_START_DATE', 'NIBRS_CT_START_DATE',
#        'NIBRS_MULTI_BIAS_START_DATE', 'NIBRS_OFF_ETH_START_DATE',
#        'COVERED_FLAG', 'COUNTY_NAME', 'MSA_NAME', 'PUBLISHABLE_FLAG',
#        'PARTICIPATED', 'NIBRS_PARTICIPATED'],
#       dtype='object')

# %%
pd.set_option('display.max_rows', None)
agencies[np.array(("UCR_AGENCY_NAME", "NCIC_AGENCY_NAME", "PUB_AGENCY_NAME", "DIVISION_NAME", "REGION_NAME", "NIBRS_START_DATE", "COUNTY_NAME", "NIBRS_PARTICIPATED"))]
# Out:
#                                UCR_AGENCY_NAME  \
# 0                                    PALESTINE
# 1                                    FRANKSTON
# 2                                      ANDREWS
# 3                                       DIBOLL
# 4                                   HUNTINGTON
# 5                                       LUFKIN
# 6                                 ARANSAS PASS
# 7                                     ROCKPORT
# 8                                  ARCHER CITY
# 9                                    ARMSTRONG
# 10                                    ATASCOSA
# 11                                       LYTLE
# 12                                  PLEASANTON
# 13                                   BELLVILLE
# 14                                       SEALY
# 15                                      WALLIS
# 16                                      BAILEY
# 17                                    MULESHOE
# 18                                     BANDERA
# 19                                     BASTROP
# 20                                       ELGIN
# 21                                  SMITHVILLE
# 22                                     SEYMOUR
# 23                                         BEE
# 24                              HARKER HEIGHTS
# 25                                      TEMPLE
# 26                                ISD: KILLEEN
# 27                                      SALADO
# 28                               ALAMO HEIGHTS
# 29                            BALCONES HEIGHTS
# 30                                CASTLE HILLS
# 31                                    CONVERSE
# 32                        HILL COUNTRY VILLAGE
# 33                              HOLLYWOOD PARK
# 34                                       KIRBY
# 35                                 LEON VALLEY
# 36                                  OLMOS PARK
# 37                              UNIVERSAL CITY
# 38                                   WINDCREST
# 39                    U OF TX:HEA SCI CT,SAN A
# 40                                 ISD: JUDSON
# 41                                     HELOTES
# 42                       ST. MARY'S UNIVERSITY
# 43                             FAIR OAKS RANCH
# 44                                      BLANCO
# 45                                      BLANCO
# 46                                      BORDEN
# 47                                      BOSQUE
# 48                                     CLIFTON
# 49                                VALLEY MILLS
# 50                                WAKE VILLAGE
# 51                                       ALVIN
# 52                                    ANGLETON
# 53                                       CLUTE
# 54                                    FREEPORT
# 55                                      MANVEL
# 56                                    PEARLAND
# 57                                      SWEENY
# 58                               WEST COLUMBIA
# 59                                    BRAZORIA
# 60                              SURFSIDE BEACH
# 61                                OYSTER CREEK
# 62                                 IOWA COLONY
# 63                               ISD: ANGLETON
# 64                             COLLEGE STATION
# 65                    TX A&M UN:COLLEGE STATIO
# 66                                    BREWSTER
# 67                    SUL ROSS STATE UNIVERSIT
# 68                                     BRISCOE
# 69                                       BROWN
# 70                                   BROWNWOOD
# 71                                       EARLY
# 72                                      BURNET
# 73                                      BURNET
# 74                                MARBLE FALLS
# 75                               HORSESHOE BAY
# 76                                    CALDWELL
# 77                                    LOCKHART
# 78                                     CALHOUN
# 79                                 PORT LAVACA
# 80                                       BAIRD
# 81                                 BROWNSVILLE
# 82                                      COMBES
# 83                                   HARLINGEN
# 84                                 LOS FRESNOS
# 85                                 PORT ISABEL
# 86                                   RIO HONDO
# 87                          SOUTH PADRE ISLAND
# 88                                LAGUNA VISTA
# 89                                        CAMP
# 90                                   PITTSBURG
# 91                                        CASS
# 92                              HUGHES SPRINGS
# 93                                      CASTRO
# 94                                     DIMMITT
# 95                                    CHAMBERS
# 96                                MONT BELVIEU
# 97                           ISD: BARBERS HILL
# 98                                    CHEROKEE
# 99                                JACKSONVILLE
# 100                                       RUSK
# 101                                      CUNEY
# 102                                  CHILDRESS
# 103                                    COCHRAN
# 104                                 SANTA ANNA
# 105                                     COLLIN
# 106                                     CELINA
# 107                               FARMERSVILLE
# 108                                     FRISCO
# 109                                   MCKINNEY
# 110                                      PLANO
# 111                                    PROSPER
# 112                                      WYLIE
# 113                                  PRINCETON
# 114                                    MELISSA
# 115                                     MURPHY
# 116                                     PARKER
# 117                                   COLORADO
# 118                                   COLUMBUS
# 119                              NEW BRAUNFELS
# 120                               GARDEN RIDGE
# 121                                   BULVERDE
# 122                                   COMANCHE
# 123                                      COOKE
# 124                                GAINESVILLE
# 125                                 GATESVILLE
# 126                                      CRANE
# 127                                   CROCKETT
# 128                                     CROSBY
# 129                                      RALLS
# 130                                    DALHART
# 131                                    ADDISON
# 132                              BALCH SPRINGS
# 133                                 CEDAR HILL
# 134                                    COPPELL
# 135                                     DESOTO
# 136                                DUNCANVILLE
# 137                             FARMERS BRANCH
# 138                              GRAND PRAIRIE
# 139                              HIGHLAND PARK
# 140                                  LANCASTER
# 141                                   MESQUITE
# 142                                 RICHARDSON
# 143                                     SACHSE
# 144                                 SEAGOVILLE
# 145                            UNIVERSITY PARK
# 146                         UNIV OF TX: DALLAS
# 147                                    ROWLETT
# 148                              GLENN HEIGHTS
# 149                                     DAWSON
# 150                                 DEAF SMITH
# 151                                      DELTA
# 152                                     DENTON
# 153                                     DENTON
# 154                                LAKE DALLAS
# 155                                 LEWISVILLE
# 156                                     SANGER
# 157                   TEXAS WOMAN'S UNIVERSITY
# 158                               FLOWER MOUND
# 159                                 THE COLONY
# 160                           HIGHLAND VILLAGE
# 161                                    CORINTH
# 162                                 DOUBLE OAK
# 163                                    ROANOKE
# 164                                     PONDER
# 165                                  NORTHLAKE
# 166                                     DEWITT
# 167                                      CUERO
# 168                                     DONLEY
# 169                                      DUVAL
# 170                                   EASTLAND
# 171                                      CISCO
# 172                                   EASTLAND
# 173                                      ELLIS
# 174                                      ENNIS
# 175                                 MIDLOTHIAN
# 176                                    RED OAK
# 177                                 WAXAHACHIE
# 178                                    EL PASO
# 179                                    EL PASO
# 180                                      ERATH
# 181                                     DUBLIN
# 182                   TARLETON STATE UNIVERSIT
# 183                                  LA GRANGE
# 184                                SCHULENBURG
# 185                                      FLOYD
# 186                                   FLOYDADA
# 187                                      FOARD
# 188                                  FORT BEND
# 189                              MISSOURI CITY
# 190                                  ROSENBERG
# 191                                   STAFFORD
# 192                                 SUGAR LAND
# 193                                  FREESTONE
# 194                                     TEAGUE
# 195                                    WORTHAM
# 196                                   PEARSALL
# 197                                   SEMINOLE
# 198                                  DICKINSON
# 199                                FRIENDSWOOD
# 200                                  GALVESTON
# 201                                      KEMAH
# 202                                LEAGUE CITY
# 203                                 TEXAS CITY
# 204                              JAMAICA BEACH
# 205                                   SANTA FE
# 206                                  GLASSCOCK
# 207                                     GOLIAD
# 208                                    WAELDER
# 209                                       GRAY
# 210                                      PAMPA
# 211                                    DENISON
# 212                                    SHERMAN
# 213                                      TIOGA
# 214                                 GLADEWATER
# 215                                    KILGORE
# 216                                   LONGVIEW
# 217                                  WHITE OAK
# 218                                   NAVASOTA
# 219                                     SEGUIN
# 220                                     CIBOLO
# 221                                  ABERNATHY
# 222                                  PLAINVIEW
# 223                                       HALL
# 224                                    MEMPHIS
# 225                                   HAMILTON
# 226                                   HAMILTON
# 227                                   HANSFORD
# 228                                   SPEARMAN
# 229                                   HARDEMAN
# 230                                    SILSBEE
# 231                                  SOUR LAKE
# 232                                  LUMBERTON
# 233                                  DEER PARK
# 234                             JERSEY VILLAGE
# 235                                   LA PORTE
# 236                                   PASADENA
# 237                                   SEABROOK
# 238                              SOUTH HOUSTON
# 239                            SOUTHSIDE PLACE
# 240                              SPRING VALLEY
# 241                                    TOMBALL
# 242                                       KATY
# 243                                 NASSAU BAY
# 244                        UNIV OF TX: HOUSTON
# 245                   UN OF HOUSTON:CENTRAL CA
# 246                             HEDWIG VILLAGE
# 247                   UN OF HOUSTON:DOWNTOWN C
# 248                   LONE STAR COL SYSTEM DST
# 249                                 ISD: KLEIN
# 250                                   LAKEVIEW
# 251                   PORT OF HOUSTON AUTHORTY
# 252                                ISD: SPRING
# 253                              ISD: PASADENA
# 254                                ISD: ALDINE
# 255                                   HARRISON
# 256                                 HALLSVILLE
# 257                                    HASKELL
# 258                                 SAN MARCOS
# 259                     TX ST UNIV, SAN MARCOS
# 260                                       KYLE
# 261                                   HEMPHILL
# 262                                     ATHENS
# 263                            GUN BARREL CITY
# 264                                       TOOL
# 265                                    HIDALGO
# 266                                      ALAMO
# 267                                      DONNA
# 268                                    EDCOUCH
# 269                                   SAN JUAN
# 270                                   PALMVIEW
# 271                                      ALTON
# 272                                    PENITAS
# 273                              SULLIVAN CITY
# 274                                  PALMHURST
# 275                                       HILL
# 276                                  HILLSBORO
# 277                                     ITASCA
# 278                                    HOCKLEY
# 279                                  LEVELLAND
# 280                                       HOOD
# 281                                   GRANBURY
# 282                                    HOPKINS
# 283                            SULPHUR SPRINGS
# 284                                    HOUSTON
# 285                                  GRAPELAND
# 286                                     HOWARD
# 287                                 BIG SPRING
# 288                                   HUDSPETH
# 289                                       HUNT
# 290                                 GREENVILLE
# 291                   TEXAS A&M UNIV: COMMERCE
# 292                                     BORGER
# 293                                      IRION
# 294                                    JACKSON
# 295                                       EDNA
# 296                                     JASPER
# 297                                  NEDERLAND
# 298                                PORT ARTHUR
# 299                                PORT NECHES
# 300                                   JIM HOGG
# 301                                    JOHNSON
# 302                                   BURLESON
# 303                                   CLEBURNE
# 304                                     JOSHUA
# 305                                      KEENE
# 306                                     GODLEY
# 307                                      ANSON
# 308                                     HAMLIN
# 309                                     KARNES
# 310                                     KENEDY
# 311                                    KAUFMAN
# 312                                     FORNEY
# 313                                    KAUFMAN
# 314                                       KEMP
# 315                                    TERRELL
# 316                                   CRANDALL
# 317                                    KENDALL
# 318                                     BOERNE
# 319                                     KENEDY
# 320                                  KERRVILLE
# 321                                     INGRAM
# 322                                   JUNCTION
# 323                                  KNOX CITY
# 324                         RENO, LAMAR COUNTY
# 325                                LITTLEFIELD
# 326                                      SUDAN
# 327                                   LAMPASAS
# 328                                   LAMPASAS
# 329                                     LAVACA
# 330                              HALLETTSVILLE
# 331                                     YOAKUM
# 332                                        LEE
# 333                                   GIDDINGS
# 334                                       LEON
# 335                                    LIBERTY
# 336                                     DAYTON
# 337                                  GROESBECK
# 338                                      MEXIA
# 339                                   LIPSCOMB
# 340                               THREE RIVERS
# 341                                      LLANO
# 342                                      LLANO
# 343                      SUNRISE BEACH VILLAGE
# 344                                     LOVING
# 345                                    LUBBOCK
# 346                                     IDALOU
# 347                                    LUBBOCK
# 348                        TX TECH UN: LUBBOCK
# 349                                  WOLFFORTH
# 350                                       LYNN
# 351                                     TAHOKA
# 352                                  O'DONNELL
# 353                                  MCCULLOCH
# 354                                      BRADY
# 355                                   MCLENNAN
# 356                                   BELLMEAD
# 357                                     HEWITT
# 358                              LACY-LAKEVIEW
# 359                                     LORENA
# 360                                   ROBINSON
# 361                                       WACO
# 362                                       WEST
# 363                                    WOODWAY
# 364                   MCLENNAN COMMUNITY COLLE
# 365                       TX ST TECH COL: WACO
# 366                            BRUCEVILLE-EDDY
# 367                                    MADISON
# 368                               MADISONVILLE
# 369                                     MARION
# 370                                     MARTIN
# 371                                      MASON
# 372                                   BAY CITY
# 373                                   PALACIOS
# 374                              ISD: BAY CITY
# 375                                CASTROVILLE
# 376                                     DEVINE
# 377                                    CAMERON
# 378                                   ROCKDALE
# 379                                  THORNDALE
# 380                                      MILLS
# 381                                   MONTAGUE
# 382                                     CONROE
# 383                                   MAGNOLIA
# 384                                 SHENANDOAH
# 385                            OAK RIDGE NORTH
# 386                                 MONTGOMERY
# 387                                ISD: CONROE
# 388                                      MOORE
# 389                                      DUMAS
# 390                                     CACTUS
# 391                               DAINGERFIELD
# 392                                  LONE STAR
# 393                                     NAPLES
# 394                                NACOGDOCHES
# 395                                NACOGDOCHES
# 396                   STEPHEN F. AUSTIN ST UNI
# 397                                    NAVARRO
# 398                                  CORSICANA
# 399                                     KERENS
# 400                                     NEWTON
# 401                                      NOLAN
# 402                                 SWEETWATER
# 403                             CORPUS CHRISTI
# 404                                   DRISCOLL
# 405                                  OCHILTREE
# 406                                   PERRYTON
# 407                                     ORANGE
# 408                                BRIDGE CITY
# 409                                     ORANGE
# 410                                  PINEHURST
# 411                                      VIDOR
# 412                                WEST ORANGE
# 413                                 PALO PINTO
# 414                              MINERAL WELLS
# 415                                   CARTHAGE
# 416                                     PARKER
# 417                                HUDSON OAKS
# 418                                WILLOW PARK
# 419                                     BOVINA
# 420                                     FRIONA
# 421                                    FARWELL
# 422                              FORT STOCKTON
# 423                                       POLK
# 424                                 LIVINGSTON
# 425                                   CORRIGAN
# 426                                   ONALASKA
# 427                                     POTTER
# 428                                   AMARILLO
# 429                           AMARILLO COLLEGE
# 430                                   PRESIDIO
# 431                                     CANYON
# 432                     WEST TX A&M UNIVERSITY
# 433                                     REAGAN
# 434                                       REAL
# 435                                  RED RIVER
# 436                                      PECOS
# 437                                    ROBERTS
# 438                                  ROBERTSON
# 439                                    BREMOND
# 440                                    CALVERT
# 441                                     HEARNE
# 442                                   ROCKWALL
# 443                                   ROCKWALL
# 444                                 ROYSE CITY
# 445                                      HEATH
# 446                                    RUNNELS
# 447                                  BALLINGER
# 448                                    WINTERS
# 449                                      MILES
# 450                                       RUSK
# 451                                  HENDERSON
# 452                                    OVERTON
# 453                                      TATUM
# 454                                     SABINE
# 455                                   PINELAND
# 456                              SAN AUGUSTINE
# 457                                   PORTLAND
# 458                                     SINTON
# 459                                       TAFT
# 460                                   SAN SABA
# 461                                 SCHLEICHER
# 462                                     SNYDER
# 463                                SHACKELFORD
# 464                                     SHELBY
# 465                                     CENTER
# 466                                        ARP
# 467                                    LINDALE
# 468                                      TYLER
# 469                                 WHITEHOUSE
# 470                       TYLER JUNIOR COLLEGE
# 471                                    BULLARD
# 472                                  LA GRULLA
# 473                            RIO GRANDE CITY
# 474                                       ROMA
# 475                                   STEPHENS
# 476                               BRECKENRIDGE
# 477                                   STERLING
# 478                                     SUTTON
# 479                                     SONORA
# 480                                    SWISHER
# 481                                      TULIA
# 482                                    TARRANT
# 483                                  ARLINGTON
# 484                                    BEDFORD
# 485                                 BLUE MOUND
# 486                                    CROWLEY
# 487                     DALWORTHINGTON GARDENS
# 488                                    EVERMAN
# 489                                 FORT WORTH
# 490                                  GRAPEVINE
# 491                                      HURST
# 492                                  KENNEDALE
# 493                                  MANSFIELD
# 494                       NORTH RICHLAND HILLS
# 495                                 RIVER OAKS
# 496                                    WATAUGA
# 497                             WESTOVER HILLS
# 498                                  WESTWORTH
# 499                                    PANTEGO
# 500                   DALLAS-FORT WORTH INT AP
# 501                                COLLEYVILLE
# 502                                PELICAN BAY
# 503                   HOS DIST: TARRANT COUNTY
# 504                                    ABILENE
# 505                                        TYE
# 506                                 BROWNFIELD
# 507                                      TITUS
# 508                             MOUNT PLEASANT
# 509                                 SAN ANGELO
# 510                    ANGELO STATE UNIVERSITY
# 511                                     TRAVIS
# 512                                     AUSTIN
# 513                                      MANOR
# 514                            WEST LAKE HILLS
# 515                         UNIV OF TX: AUSTIN
# 516                               PFLUGERVILLE
# 517                                    LAKEWAY
# 518                              SUNSET VALLEY
# 519                              MUSTANG RIDGE
# 520                                ISD: AUSTIN
# 521                                   BEE CAVE
# 522                          ISD: PFLUGERVILLE
# 523                                      TYLER
# 524                                     GILMER
# 525                                   ORE CITY
# 526                                      UPTON
# 527                                  VAN ZANDT
# 528                               GRAND SALINE
# 529                                WILLS POINT
# 530                                   VICTORIA
# 531                                   VICTORIA
# 532                                     WALKER
# 533                                 HUNTSVILLE
# 534                                 BROOKSHIRE
# 535                                     WALLER
# 536                                  HEMPSTEAD
# 537                                       WARD
# 538                                 WASHINGTON
# 539                                    BRENHAM
# 540                                       WEBB
# 541                                     LAREDO
# 542                                    WHARTON
# 543                                   EL CAMPO
# 544                                    WHARTON
# 545                                    WHEELER
# 546                                    ELECTRA
# 547                                  IOWA PARK
# 548                   MIDWESTERN STATE UNIVERS
# 549                                  WILBARGER
# 550                                     VERNON
# 551                                    WILLACY
# 552                                     LYFORD
# 553                                 WILLIAMSON
# 554                                   FLORENCE
# 555                                 GEORGETOWN
# 556                    SOUTHWESTERN UNIVERSITY
# 557                                 CEDAR PARK
# 558                                    LEANDER
# 559                                    JARRELL
# 560                                     WILSON
# 561                                FLORESVILLE
# 562                           ISD: FLORESVILLE
# 563                                       WISE
# 564                                 BRIDGEPORT
# 565                                    DECATUR
# 566                                RUNAWAY BAY
# 567                                    QUITMAN
# 568                                  WINNSBORO
# 569                                      YOUNG
# 570                                     GRAHAM
# 571                                      OLNEY
# 572                                     ZAVALA
# 573                                     DALLAS
# 574                                    HOUSTON
# 575                                  NORTHEAST
# 576                                      VENUS
# 577                        PORT OF BROWNSVILLE
# 578                                    MOULTON
# 579                                BARTONVILLE
# 580                                  RIO BRAVO
# 581                        ISD: CALHOUN COUNTY
# 582                                   FULSHEAR
# 583                                ISD: IDALOU
# 584                                     NEWTON
# 585                                    NATALIA
# 586                            ISD: BRAZOSPORT
# 587                                   CHANDLER
# 588                                       FATE
# 589           TRINITY VALLEY COMMUNITY COLLEGE
# 590                                 BROWNSBORO
# 591                                 PETERSBURG
# 592               LUBBOCK CHRISTIAN UNIVERSITY
# 593                                   GARRISON
# 594                                ISD: AUBREY
# 595                                HONEY GROVE
# 596                                     ROGERS
# 597  SOUTHWESTERN BAPTIST THEOLOGICAL SEMINARY
# 598                                   LAKEPORT
# 599                                     TENAHA
# 600                                     GUNTER
# 601                                       ALBA
# 602                                     DAWSON
# 603                           ISD: DUNCANVILLE
# 604                                 ISD: HUTTO
# 605                             ISD: MANSFIELD
# 606                               ISD: TERRELL
# 607            DALLAS COUNTY COMM COLLEGE DIST
# 608                                      EMORY
# 609                            KILGORE COLLEGE
# 610                                  ISD: ROMA
# 611                                  WOODSBORO
# 612                                      SAVOY
# 613                                      BELLS
# 614                     DENTON CNTY WATER DIST
# 615                               ISD: WHARTON
# 616                            ISD: PLEASANTON
# 617                             ISD: NORTHSIDE
# 618                             ISD: VAN VLECK
# 619          AUSTIN COMMUNITY COLLEGE DISTRICT
# 620                               ISD: TRINITY
#
#                                    NCIC_AGENCY_NAME  \
# 0                             PALESTINE POLICE DEPT
# 1                                      FRANKSTON PD
# 2                                        ANDREWS PD
# 3                                DIBOLL POLICE DEPT
# 4                                     HUNTINGTON PD
# 5                                         LUFKIN PD
# 6                                   ARANSAS PASS PD
# 7                                       ROCKPORT PD
# 8                     ARCHER CITY POLICE DEPARTMENT
# 9                            ARMSTRONG CO SO CLAUDE
# 10                        ATASCOSA CO SO JOURDANTON
# 11                                         LYTLE PD
# 12                                    PLEASANTON PD
# 13                                     BELLVILLE PD
# 14                                         SEALY PD
# 15                                        WALLIS PD
# 16                            BAILEY CO SO MULESHOE
# 17                                      MULESHOE PD
# 18                            BANDERA CO SO BANDERA
# 19                                       BASTROP PD
# 20                                         ELGIN PD
# 21                                    SMITHVILLE PD
# 22                                       SEYMOUR PD
# 23                               BEE CO SO BEEVILLE
# 24                                HARKER HEIGHTS PD
# 25                                        TEMPLE PD
# 26            KILLEEN ISD POLICE DEPARTMENT KILLEEN
# 27              VILLAGE OF SALADO POLICE DEPARTMENT
# 28                     ALAMO HEIGHTS PD SAN ANTONIO
# 29                     BALCONES HEIGHTS POLICE DEPT
# 30                         CASTLE HILLS POLICE DEPT
# 31                                      CONVERSE PD
# 32                 HILL COUNTRY VILLAGE POLICE DEPT
# 33                       HOLLYWOOD PARK POLICE DEPT
# 34                             KIRBY PD SAN ANTONIO
# 35                       LEON VALLEY PD SAN ANTONIO
# 36                        OLMOS PARK PD SAN ANTONIO
# 37                 UNIVERSAL CITY PD UNIVERSAL CITY
# 38                            WINDCREST POLICE DEPT
# 39     UNIVERSITY OF TEXAS HEALTH SCIENCE CENTER PD
# 40   JUDSON INDEP SCHOOL DISTRICT POLICE DEPT BEXAR
# 41                              HELOTES POLICE DEPT
# 42            ST MARYS UNIVERSITY POLICE DEPARTMENT
# 43                FAIR OAKS RANCH POLICE DEPARTMENT
# 44                    BLANCO COUNTY SHERIFFS OFFICE
# 45                                        BLANCO PD
# 46                                BORDEN CO SO GAIL
# 47                            BOSQUE CO SO MERIDIAN
# 48                                       CLIFTON PD
# 49                       VALLEY MILLS POLICE DEPART
# 50                         WAKE VILLAGE POLICE DEPT
# 51                                         ALVIN PD
# 52                                      ANGLETON PD
# 53                                         CLUTE PD
# 54                                      FREEPORT PD
# 55                                        MANVEL PD
# 56                             PEARLAND POLICE DEPT
# 57                                        SWEENY PD
# 58                                 WEST COLUMBIA PD
# 59                                      BRAZORIA PD
# 60                 SURFSIDE BEACH PD SURFSIDE BEACH
# 61                                  OYSTER CREEK PD
# 62        IOWA COLONY POLICE DEPARTMENT IOWA COLONY
# 63                    ANGLETON INDEP SCHOOL DIST PD
# 64                               COLLEGE STATION PD
# 65                        TEXAS A & M UNIVERSITY PD
# 66                            BREWSTER CO SO ALPINE
# 67        SUL ROSS STATE UNIV DEPT OF PUBLIC SAFETY
# 68                          BRISCOE CO SO SILVERTON
# 69                            BROWN CO SO BROWNWOOD
# 70                      BROWNWOOD POLICE DEPARTMENT
# 71                               EARLY PD BROWNWOOD
# 72                              BURNET CO SO BURNET
# 73                                        BURNET PD
# 74                                  MARBLE FALLS PD
# 75                  HORSESHOE BAY POLICE DEPARTMENT
# 76                          CALDWELL CO SO LOCKHART
# 77                                      LOCKHART PD
# 78                        CALHOUN CO SO PORT LAVACA
# 79                          PORT LAVACA POLICE DEPT
# 80                                         BAIRD PD
# 81                                   BROWNSVILLE PD
# 82                               COMBES POLICE DEPT
# 83                                     HARLINGEN PD
# 84                                   LOS FRESNOS PD
# 85                                   PORT ISABEL PD
# 86                                     RIO HONDO PD
# 87                            PD SOUTH PADRE ISLAND
# 88                         LAGUNA VISTA POLICE DEPT
# 89                             CAMP CO SO PITTSBURG
# 90                                     PITTSBURG PD
# 91                                CASS CO SO LINDEN
# 92                                   HUGHES SPRINGS
# 93                             CASTRO CO SO DIMMITT
# 94                        DIMMITT POLICE DEPARTMENT
# 95                           CHAMBERS CO SO ANAHUAC
# 96                     MONT BELVIEU PD MONT BELVIEU
# 97               BARBERS HILL ISD POLICE DEPARTMENT
# 98                              CHEROKEE CO SO RUSK
# 99                                  JACKSONVILLE PD
# 100                                         RUSK PD
# 101                                        CUNEY PD
# 102                                    CHILDRESS PD
# 103                            COCHRAN CO SO MORTON
# 104                                   SANTA ANNA PD
# 105                   COLLIN COUNTY SHERIFFS OFFICE
# 106                                       CELINA PD
# 107                                 FARMERSVILLE PD
# 108                                       FRISCO PD
# 109                                     MCKINNEY PD
# 110                                        PLANO PD
# 111                                      PROSPER PD
# 112                                        WYLIE PD
# 113                                    PRINCETON PD
# 114                       MELISSA POLICE DEPARTMENT
# 115                                       MURPHY PD
# 116                                PARKER PD PARKER
# 117                         COLORADO CO SO COLUMBUS
# 118                                     COLUMBUS PD
# 119                                NEW BRAUNFELS PD
# 120                                    GARDEN RIDGE
# 121                      BULVERDE POLICE DEPARTMENT
# 122                                     COMANCHE PD
# 123                         COOKE CO SO GAINESVILLE
# 124                                  GAINESVILLE PD
# 125                                   GATESVILLE PD
# 126                    CRANE COUNTY SHERIFFS OFFICE
# 127                            CROCKETT CO SO OZONA
# 128                          CROSBY CO SO CROSBYTON
# 129                                        RALLS PD
# 130                                      DALHART PD
# 131                                      ADDISON PD
# 132                  BALCH SPRINGS PD BALCH SPRINGS
# 133                                   CEDAR HILL PD
# 134                                      COPPELL PD
# 135                                      DE SOTO PD
# 136                                  DUNCANVILLE PD
# 137                        FARMERS BRANCH PD DALLAS
# 138                                GRAND PRAIRIE PD
# 139                         HIGHLAND PARK PD DALLAS
# 140                                    LANCASTER PD
# 141                                     MESQUITE PD
# 142                                   RICHARDSON PD
# 143                        SACHSE POLICE DEPARTMENT
# 144                                   SEAGOVILLE PD
# 145                       UNIVERSITY PARK PD DALLAS
# 146                         UNIV OF TEXAS PD DALLAS
# 147                                      ROWLETT PD
# 148                 GLENN HEIGHTS POLICE DEPARTMENT
# 149                             DAWSON CO SO LAMESA
# 150                       DEAF SMITH CO SO HEREFORD
# 151                              DELTA CO SO COOPER
# 152                             DENTON CO SO DENTON
# 153                                       DENTON PD
# 154                                  LAKE DALLAS PD
# 155                                   LEWISVILLE PD
# 156                        SANGER POLICE DEPARTMENT
# 157                     TEXAS WOMAN'S UNIVERSITY PD
# 158                    FLOWER MOUND PD FLOWER MOUND
# 159                        THE COLONY PD THE COLONY
# 160                  HIGHLAND VILLAGE PD LEWISVILLE
# 161                               CORINTH PD DENTON
# 162                                   DOUBLE OAK PD
# 163                             ROANOKE POLICE DEPT
# 164                 PONDER POLICE DEPARTMENT PONDER
# 165                     NORTHLAKE POLICE DEPARTMENT
# 166                   DEWITT COUNTY SHERIFFS OFFICE
# 167                                        CUERO PD
# 168                          DONLEY CO SO CLARENDON
# 169                           DUVAL CO SO SAN DIEGO
# 170                         EASTLAND CO SO EASTLAND
# 171                                        CISCO PD
# 172                                     EASTLAND PD
# 173                          ELLIS CO SO WAXAHACHIE
# 174                                        ENNIS PD
# 175                                   MIDLOTHIAN PD
# 176                       RED OAK POLICE DEPARTMENT
# 177                                   WAXAHACHIE PD
# 178                                         EL PASO
# 179                                      EL PASO PD
# 180                        ERATH CO SO STEPHENVILLE
# 181                                       DUBLIN PD
# 182         TARLETON STATE UNIVSITY PD STEPHENVILLE
# 183                                    LA GRANGE PD
# 184                                  SCHULENBURG PD
# 185                            FLOYD CO SO FLOYDADA
# 186                                     FLOYDADA PD
# 187                             FOARD CO SO CROWELL
# 188                        FORT BEND CO SO RICHMOND
# 189                                MISSOURI CITY PD
# 190                           ROSENBERG POLICE DEPT
# 191                                     STAFFORD PD
# 192                                   SUGAR LAND PD
# 193                       FREESTONE CO SO FAIRFIELD
# 194                                       TEAGUE PD
# 195                                      WORTHAM PD
# 196                                     PEARSALL PD
# 197                                     SEMINOLE PD
# 198                                    DICKINSON PD
# 199                                  FRIENDSWOOD PD
# 200                                    GALVESTON PD
# 201                                        KEMAH PD
# 202                                  LEAGUE CITY PD
# 203                                   TEXAS CITY PD
# 204                      JAMAICA BEACH PD GALVESTON
# 205                                     SANTE FE PD
# 206                     GLASSCOCK CO SO GARDEN CITY
# 207                   GOLIAD COUNTY SHERIFFS OFFICE
# 208                                      WAELDER PD
# 209                                GRAY CO SO PAMPA
# 210                                        PAMPA PD
# 211                                      DENISON PD
# 212                             SHERMAN POLICE DEPT
# 213                         TIOGA POLICE DEPARTMENT
# 214                                   GLADEWATER PD
# 215                                      KILGORE PD
# 216                                     LONGVIEW PD
# 217                                    WHITE OAK PD
# 218                                     NAVASOTA PD
# 219                                       SEGUIN PD
# 220                                CIBOLO PD CIBOLO
# 221                                    ABERNATHY PD
# 222                                    PLAINVIEW PD
# 223                              HALL CO SO MEMPHIS
# 224                                      MEMPHIS PD
# 225                         HAMILTON CO SO HAMILTON
# 226                                     HAMILTON PD
# 227                 HANSFORD COUNTY SHERIFFS OFFICE
# 228                                     SPEARMAN PD
# 229                           HARDEMAN CO SO QUANAH
# 230                                      SILSBEE PD
# 231                            SOURLAKE POLICE DEPT
# 232                                    LUMBERTON PD
# 233                                    DEER PARK PD
# 234                       JERSEY VILLAGE PD HOUSTON
# 235                                     LA PORTE PD
# 236                                     PASADENA PD
# 237                                     SEABROOK PD
# 238                                SOUTH HOUSTON PD
# 239                     SOUTH SIDE PLACE PD HOUSTON
# 240         SPRING VALLEY VILLAGE POLICE DEPARTMENT
# 241                                      TOMBALL PD
# 242                                         KATY PD
# 243                    NASSAU BAY POLICE DEPARTMENT
# 244                  UNIVERSITY OF TEXAS PD HOUSTON
# 245                      UNIV OF HOUSTON PD HOUSTON
# 246                       HEDWIG VILLAGE PD HOUSTON
# 247     UNIV OF HOUSTON/DOWNTOWN COLLEGE PD HOUSTON
# 248            LONE STAR COLLEGE SYSTEM DIST POLICE
# 249            KLEIN INDEPENDENT SCHL DIST PD KLEIN
# 250                      LAKEVIEW POLICE DEPARTMENT
# 251        PORT OF HOUSTON AUTH POLICE DEPT HOUSTON
# 252  SPRING INDEPENDENT SCHOOL DISTRICT POLICE DEPT
# 253                        PASADENA ISD POLICE DEPT
# 254   ALDINE INDEPENDENT SCHOOL DISTRICT PD HOUSTON
# 255                         HARRISON CO SO MARSHALL
# 256                                   HALLSVILLE PD
# 257                                      HASKELL PD
# 258                                   SAN MARCOS PD
# 259        TEXAS STATE UNIVERSITY POLICE DEPARTMENT
# 260                                         KYLE PD
# 261                         HEMPHILL CO SO CANADIAN
# 262                                       ATHENS PD
# 263                              GUN BARREL CITY PD
# 264                                    TOOL PD KEMP
# 265                          HIDALGO CO SO EDINBURG
# 266                                        ALAMO PD
# 267                               DONNA POLICE DEPT
# 268                                      EDCOUCH PD
# 269                                     SAN JUAN PD
# 270              PALMVIEW POLICE DEPARTMENT MISSION
# 271                 ALTON POLICE DEPARTMENT MISSION
# 272                  CITY PENITAS POLICE DEPARTMENT
# 273                 SULLIVAN CITY POLICE DEPARTMENT
# 274                     PALMHURST POLICE DEPARTMENT
# 275                            HILL CO SO HILLSBORO
# 276                                    HILLSBORO PD
# 277                                       ITASCA PD
# 278                         HOCKLEY CO SO LEVELLAND
# 279                                    LEVELLAND PD
# 280                             HOOD CO SO GRANBURY
# 281                                     GRANBURY PD
# 282                   HOPKINS CO SO SULPHUR SPRINGS
# 283                              SULPHUR SPRINGS PD
# 284                          HOUSTON CO SO CROCKETT
# 285                     GRAPELAND POLICE DEPARTMENT
# 286                   HOWARD COUNTY SHERIFFS OFFICE
# 287                    BIG SPRING POLICE DEPARTMENT
# 288                    HUDSPETH CO SO SIERRA BLANCA
# 289                           HUNT CO SO GREENVILLE
# 290                                   GREENVILLE PD
# 291                TEXAS A&M UNIVERSITY PD COMMERCE
# 292                                       BORGER PD
# 293                             IRION CO SO MERTZON
# 294                              JACKSON CO SO EDNA
# 295                                         EDNA PD
# 296                                       JASPER PD
# 297                                    NEDERLAND PD
# 298                         PORT ARTHUR POLICE DEPT
# 299                                  PORT NECHES PD
# 300                     JIM HOGG CO SO HEBBRONVILLE
# 301                          JOHNSON CO SO CLEBURNE
# 302                                     BURLESON PD
# 303                                     CLEBURNE PD
# 304                                       JOSHUA PD
# 305                                        KEENE PD
# ...
# 336                        LIBERTY                  Y
# 337                      LIMESTONE                  Y
# 338                      LIMESTONE                  Y
# 339                       LIPSCOMB                  Y
# 340                       LIVE OAK                  Y
# 341                          LLANO                  Y
# 342                          LLANO                  Y
# 343                          LLANO                  Y
# 344                         LOVING                  Y
# 345                        LUBBOCK                  Y
# 346                        LUBBOCK                  Y
# 347                        LUBBOCK                  Y
# 348                        LUBBOCK                  Y
# 349                        LUBBOCK                  Y
# 350                           LYNN                  Y
# 351                           LYNN                  Y
# 352                   DAWSON; LYNN                  Y
# 353                      MCCULLOCH                  Y
# 354                      MCCULLOCH                  Y
# 355                       MCLENNAN                  Y
# 356                       MCLENNAN                  Y
# 357                       MCLENNAN                  Y
# 358                       MCLENNAN                  Y
# 359                       MCLENNAN                  Y
# 360                       MCLENNAN                  Y
# 361                       MCLENNAN                  Y
# 362                       MCLENNAN                  Y
# 363                       MCLENNAN                  Y
# 364                       MCLENNAN                  Y
# 365                       MCLENNAN                  Y
# 366                FALLS; MCLENNAN                  Y
# 367                        MADISON                  Y
# 368                        MADISON                  Y
# 369                         MARION                  Y
# 370                         MARTIN                  Y
# 371                          MASON                  Y
# 372                      MATAGORDA                  Y
# 373                      MATAGORDA                  Y
# 374                      MATAGORDA                  Y
# 375                         MEDINA                  Y
# 376                         MEDINA                  Y
# 377                          MILAM                  Y
# 378                          MILAM                  Y
# 379              WILLIAMSON; MILAM                  Y
# 380                          MILLS                  Y
# 381                       MONTAGUE                  Y
# 382                     MONTGOMERY                  Y
# 383                     MONTGOMERY                  Y
# 384                     MONTGOMERY                  Y
# 385                     MONTGOMERY                  Y
# 386                     MONTGOMERY                  Y
# 387                     MONTGOMERY                  Y
# 388                          MOORE                  Y
# 389                          MOORE                  Y
# 390                          MOORE                  Y
# 391                         MORRIS                  Y
# 392                         MORRIS                  Y
# 393                         MORRIS                  Y
# 394                    NACOGDOCHES                  Y
# 395                    NACOGDOCHES                  Y
# 396                    NACOGDOCHES                  Y
# 397                        NAVARRO                  Y
# 398                        NAVARRO                  Y
# 399                        NAVARRO                  Y
# 400                         NEWTON                  Y
# 401                          NOLAN                  Y
# 402                          NOLAN                  Y
# 403                         NUECES                  Y
# 404                         NUECES                  Y
# 405                      OCHILTREE                  Y
# 406                      OCHILTREE                  Y
# 407                         ORANGE                  Y
# 408                         ORANGE                  Y
# 409                         ORANGE                  Y
# 410                         ORANGE                  Y
# 411                         ORANGE                  Y
# 412                         ORANGE                  Y
# 413                     PALO PINTO                  Y
# 414             PARKER; PALO PINTO                  Y
# 415                         PANOLA                  Y
# 416                         PARKER                  Y
# 417                         PARKER                  Y
# 418                         PARKER                  Y
# 419                         PARMER                  Y
# 420                         PARMER                  Y
# 421                         PARMER                  Y
# 422                          PECOS                  Y
# 423                           POLK                  Y
# 424                           POLK                  Y
# 425                           POLK                  Y
# 426                           POLK                  Y
# 427                         POTTER                  Y
# 428                RANDALL; POTTER                  Y
# 429                         POTTER                  Y
# 430                       PRESIDIO                  Y
# 431                        RANDALL                  Y
# 432                        RANDALL                  Y
# 433                         REAGAN                  Y
# 434                           REAL                  Y
# 435                      RED RIVER                  Y
# 436                         REEVES                  Y
# 437                        ROBERTS                  Y
# 438                      ROBERTSON                  Y
# 439                      ROBERTSON                  Y
# 440                      ROBERTSON                  Y
# 441                      ROBERTSON                  Y
# 442                       ROCKWALL                  Y
# 443                       ROCKWALL                  Y
# 444         HUNT; COLLIN; ROCKWALL                  Y
# 445                       ROCKWALL                  Y
# 446                        RUNNELS                  Y
# 447                        RUNNELS                  Y
# 448                        RUNNELS                  Y
# 449                        RUNNELS                  Y
# 450                           RUSK                  Y
# 451                           RUSK                  Y
# 452                    SMITH; RUSK                  Y
# 453                   PANOLA; RUSK                  Y
# 454                         SABINE                  Y
# 455                         SABINE                  Y
# 456                  SAN AUGUSTINE                  Y
# 457                   SAN PATRICIO                  Y
# 458                   SAN PATRICIO                  Y
# 459                   SAN PATRICIO                  Y
# 460                       SAN SABA                  Y
# 461                     SCHLEICHER                  Y
# 462                         SCURRY                  Y
# 463                    SHACKELFORD                  Y
# 464                         SHELBY                  Y
# 465                         SHELBY                  Y
# 466                          SMITH                  Y
# 467                          SMITH                  Y
# 468                          SMITH                  Y
# 469                          SMITH                  Y
# 470                          SMITH                  Y
# 471                CHEROKEE; SMITH                  Y
# 472                          STARR                  Y
# 473                          STARR                  Y
# 474                          STARR                  Y
# 475                       STEPHENS                  Y
# 476                       STEPHENS                  Y
# 477                       STERLING                  Y
# 478                         SUTTON                  Y
# 479                         SUTTON                  Y
# 480                        SWISHER                  Y
# 481                        SWISHER                  Y
# 482                        TARRANT                  Y
# 483                        TARRANT                  Y
# 484                        TARRANT                  Y
# 485                        TARRANT                  Y
# 486               JOHNSON; TARRANT                  Y
# 487                        TARRANT                  Y
# 488                        TARRANT                  Y
# 489        PARKER; DENTON; TARRANT                  Y
# 490                        TARRANT                  Y
# 491                        TARRANT                  Y
# 492                        TARRANT                  Y
# 493        ELLIS; JOHNSON; TARRANT                  Y
# 494                        TARRANT                  Y
# 495                        TARRANT                  Y
# 496                        TARRANT                  Y
# 497                        TARRANT                  Y
# 498                        TARRANT                  Y
# 499                        TARRANT                  Y
# 500                        TARRANT                  Y
# 501                        TARRANT                  Y
# 502                        TARRANT                  Y
# 503                        TARRANT                  Y
# 504                  JONES; TAYLOR                  Y
# 505                         TAYLOR                  Y
# 506                          TERRY                  Y
# 507                          TITUS                  Y
# 508                          TITUS                  Y
# 509                      TOM GREEN                  Y
# 510                      TOM GREEN                  Y
# 511                         TRAVIS                  Y
# 512             WILLIAMSON; TRAVIS                  Y
# 513                         TRAVIS                  Y
# 514                         TRAVIS                  Y
# 515                         TRAVIS                  Y
# 516             WILLIAMSON; TRAVIS                  Y
# 517                         TRAVIS                  Y
# 518                         TRAVIS                  Y
# 519               CALDWELL; TRAVIS                  Y
# 520                         TRAVIS                  Y
# 521                         TRAVIS                  Y
# 522                         TRAVIS                  Y
# 523                          TYLER                  Y
# 524                         UPSHUR                  Y
# 525                         UPSHUR                  Y
# 526                          UPTON                  Y
# 527                      VAN ZANDT                  Y
# 528                      VAN ZANDT                  Y
# 529                      VAN ZANDT                  Y
# 530                       VICTORIA                  Y
# 531                       VICTORIA                  Y
# 532                         WALKER                  Y
# 533                         WALKER                  Y
# 534                         WALLER                  Y
# 535                 HARRIS; WALLER                  Y
# 536                         WALLER                  Y
# 537                           WARD                  Y
# 538                     WASHINGTON                  Y
# 539                     WASHINGTON                  Y
# 540                           WEBB                  Y
# 541                           WEBB                  Y
# 542                        WHARTON                  Y
# 543                        WHARTON                  Y
# 544                        WHARTON                  Y
# 545                        WHEELER                  Y
# 546                        WICHITA                  Y
# 547                        WICHITA                  Y
# 548                        WICHITA                  Y
# 549                      WILBARGER                  Y
# 550                      WILBARGER                  Y
# 551                        WILLACY                  Y
# 552                        WILLACY                  Y
# 553                     WILLIAMSON                  Y
# 554                     WILLIAMSON                  Y
# 555                     WILLIAMSON                  Y
# 556                     WILLIAMSON                  Y
# 557             TRAVIS; WILLIAMSON                  Y
# 558             TRAVIS; WILLIAMSON                  Y
# 559                     WILLIAMSON                  Y
# 560                         WILSON                  Y
# 561                         WILSON                  Y
# 562                         WILSON                  Y
# 563                           WISE                  Y
# 564                           WISE                  Y
# 565                           WISE                  Y
# 566                           WISE                  Y
# 567                           WOOD                  Y
# 568                 FRANKLIN; WOOD                  Y
# 569                          YOUNG                  Y
# 570                          YOUNG                  Y
# 571                          YOUNG                  Y
# 572                         ZAVALA                  Y
# 573         DENTON; COLLIN; DALLAS                  Y
# 574  MONTGOMERY; FORT BEND; HARRIS                  Y
# 575                         DENTON                  Y
# 576                 ELLIS; JOHNSON                  Y
# 577                        CAMERON                  Y
# 578                         LAVACA                  Y
# 579                         DENTON                  Y
# 580                           WEBB                  Y
# 581                        CALHOUN                  Y
# 582                      FORT BEND                  Y
# 583                        LUBBOCK                  Y
# 584                         NEWTON                  Y
# 585                         MEDINA                  Y
# 586                       BRAZORIA                  Y
# 587                      HENDERSON                  Y
# 588                       ROCKWALL                  Y
# 589                      HENDERSON                  Y
# 590                      HENDERSON                  Y
# 591                           HALE                  Y
# 592                        LUBBOCK                  Y
# 593                    NACOGDOCHES                  Y
# 594                         DENTON                  Y
# 595                         FANNIN                  Y
# 596                           BELL                  Y
# 597                        TARRANT                  Y
# 598                          GREGG                  Y
# 599                         SHELBY                  Y
# 600                        GRAYSON                  Y
# 601                    RAINS; WOOD                  Y
# 602                        NAVARRO                  Y
# 603                         DALLAS                  Y
# 604                     WILLIAMSON                  Y
# 605                        TARRANT                  Y
# 606                        KAUFMAN                  Y
# 607                         DALLAS                  Y
# 608                          RAINS                  Y
# 609                          GREGG                  Y
# 610                          STARR                  Y
# 611                        REFUGIO                  Y
# 612                         FANNIN                  Y
# 613                        GRAYSON                  Y
# 614                         DENTON                  Y
# 615                        WHARTON                  Y
# 616                       ATASCOSA                  Y
# 617                          BEXAR                  Y
# 618                      MATAGORDA                  Y
# 619                         TRAVIS                  Y
# 620                        TRINITY                  Y

# %% [markdown]
# Are all agencies listed agencies that are NIBRS-participating?

# %%
print("no. agencies listed:\n",len(agencies))
print("no. agenices listed where NIBRS_PARTICIPATED = Y:\n",len(agencies.loc[agencies['NIBRS_PARTICIPATED']=='Y']))
# Out:
# no. agencies listed:
#  621
# no. agenices listed where NIBRS_PARTICIPATED = Y:
#  621

# %% [markdown]
# Let's look at NIBRS-participating agencies in Harris county

# %%
agencies.loc[agencies['COUNTY_NAME']=='HARRIS'][np.array(("UCR_AGENCY_NAME", "NCIC_AGENCY_NAME", "NIBRS_START_DATE", "PUB_AGENCY_NAME", "POPULATION", "AGENCY_TYPE_NAME", "SUBMITTING_AGENCY_NAME", "DIVISION_NAME", "REGION_NAME", "COUNTY_NAME", "MSA_NAME","NIBRS_PARTICIPATED", "COVERED_FLAG"))]
# Out:
#               UCR_AGENCY_NAME                                NCIC_AGENCY_NAME  \
# 233                 DEER PARK                                    DEER PARK PD
# 234            JERSEY VILLAGE                       JERSEY VILLAGE PD HOUSTON
# 235                  LA PORTE                                     LA PORTE PD
# 236                  PASADENA                                     PASADENA PD
# 237                  SEABROOK                                     SEABROOK PD
# 238             SOUTH HOUSTON                                SOUTH HOUSTON PD
# 239           SOUTHSIDE PLACE                     SOUTH SIDE PLACE PD HOUSTON
# 240             SPRING VALLEY         SPRING VALLEY VILLAGE POLICE DEPARTMENT
# 241                   TOMBALL                                      TOMBALL PD
# 243                NASSAU BAY                    NASSAU BAY POLICE DEPARTMENT
# 244       UNIV OF TX: HOUSTON                  UNIVERSITY OF TEXAS PD HOUSTON
# 245  UN OF HOUSTON:CENTRAL CA                      UNIV OF HOUSTON PD HOUSTON
# 246            HEDWIG VILLAGE                       HEDWIG VILLAGE PD HOUSTON
# 247  UN OF HOUSTON:DOWNTOWN C     UNIV OF HOUSTON/DOWNTOWN COLLEGE PD HOUSTON
# 248  LONE STAR COL SYSTEM DST            LONE STAR COLLEGE SYSTEM DIST POLICE
# 249                ISD: KLEIN            KLEIN INDEPENDENT SCHL DIST PD KLEIN
# 250                  LAKEVIEW                      LAKEVIEW POLICE DEPARTMENT
# 251  PORT OF HOUSTON AUTHORTY        PORT OF HOUSTON AUTH POLICE DEPT HOUSTON
# 252               ISD: SPRING  SPRING INDEPENDENT SCHOOL DISTRICT POLICE DEPT
# 253             ISD: PASADENA                        PASADENA ISD POLICE DEPT
# 254               ISD: ALDINE   ALDINE INDEPENDENT SCHOOL DISTRICT PD HOUSTON
#
#     NIBRS_START_DATE                     PUB_AGENCY_NAME  POPULATION  \
# 233        01-OCT-19                           Deer Park       34167
# 234        01-SEP-19                      Jersey Village        8006
# 235        01-OCT-19                            La Porte       35622
# 236        01-JAN-19                            Pasadena      153689
# 237        01-OCT-19                            Seabrook       14611
# 238        01-MAY-11                       South Houston       17655
# 239        01-JUN-18                     Southside Place        1902
# 240        01-JUL-18                       Spring Valley        4414
# 241        01-APR-06                             Tomball       11897
# 243        01-OCT-19                          Nassau Bay        4040
# 244        01-JUL-18                University of Texas:           0
# 245        01-AUG-19              University of Houston:           0
# 246        01-JAN-18                      Hedwig Village        2684
# 247        01-APR-19              University of Houston:           0
# 248        01-JAN-19  Lone Star College System District            0
# 249        01-JAN-19        Independent School District:           0
# 250        01-OCT-19           Lakeview, Harrison County        6361
# 251        01-OCT-19           Port of Houston Authority           0
# 252        01-OCT-18        Independent School District:           0
# 253        01-MAR-19        Independent School District:           0
# 254        01-FEB-17        Independent School District:           0
#
#           AGENCY_TYPE_NAME                             SUBMITTING_AGENCY_NAME  \
# 233                   City  Texas Department of Public Safety Crime Inform...
# 234                   City  Texas Department of Public Safety Crime Inform...
# 235                   City  Texas Department of Public Safety Crime Inform...
# 236                   City  Texas Department of Public Safety Crime Inform...
# 237                   City  Texas Department of Public Safety Crime Inform...
# 238                   City  Texas Department of Public Safety Crime Inform...
# 239                   City  Texas Department of Public Safety Crime Inform...
# 240                   City  Texas Department of Public Safety Crime Inform...
# 241                   City  Texas Department of Public Safety Crime Inform...
# 243                   City  Texas Department of Public Safety Crime Inform...
# 244  University or College  Texas Department of Public Safety Crime Inform...
# 245  University or College  Texas Department of Public Safety Crime Inform...
# 246                   City  Texas Department of Public Safety Crime Inform...
# 247  University or College  Texas Department of Public Safety Crime Inform...
# 248  University or College  Texas Department of Public Safety Crime Inform...
# 249                  Other  Texas Department of Public Safety Crime Inform...
# 250                   City  Texas Department of Public Safety Crime Inform...
# 251                  Other  Texas Department of Public Safety Crime Inform...
# 252                  Other  Texas Department of Public Safety Crime Inform...
# 253                  Other  Texas Department of Public Safety Crime Inform...
# 254                  Other  Texas Department of Public Safety Crime Inform...
#
#           DIVISION_NAME REGION_NAME COUNTY_NAME  \
# 233  West South Central       South      HARRIS
# 234  West South Central       South      HARRIS
# 235  West South Central       South      HARRIS
# 236  West South Central       South      HARRIS
# 237  West South Central       South      HARRIS
# 238  West South Central       South      HARRIS
# 239  West South Central       South      HARRIS
# 240  West South Central       South      HARRIS
# 241  West South Central       South      HARRIS
# 243  West South Central       South      HARRIS
# 244  West South Central       South      HARRIS
# 245  West South Central       South      HARRIS
# 246  West South Central       South      HARRIS
# 247  West South Central       South      HARRIS
# 248  West South Central       South      HARRIS
# 249  West South Central       South      HARRIS
# 250  West South Central       South      HARRIS
# 251  West South Central       South      HARRIS
# 252  West South Central       South      HARRIS
# 253  West South Central       South      HARRIS
# 254  West South Central       South      HARRIS
#
#                                  MSA_NAME NIBRS_PARTICIPATED COVERED_FLAG
# 233  Houston-The Woodlands-Sugar Land, TX                  Y            N
# 234  Houston-The Woodlands-Sugar Land, TX                  Y            N
# 235  Houston-The Woodlands-Sugar Land, TX                  Y            N
# 236  Houston-The Woodlands-Sugar Land, TX                  Y            N
# 237  Houston-The Woodlands-Sugar Land, TX                  Y            N
# 238  Houston-The Woodlands-Sugar Land, TX                  Y            N
# 239  Houston-The Woodlands-Sugar Land, TX                  Y            N
# 240  Houston-The Woodlands-Sugar Land, TX                  Y            N
# 241  Houston-The Woodlands-Sugar Land, TX                  Y            N
# 243  Houston-The Woodlands-Sugar Land, TX                  Y            N
# 244  Houston-The Woodlands-Sugar Land, TX                  Y            N
# 245  Houston-The Woodlands-Sugar Land, TX                  Y            N
# 246  Houston-The Woodlands-Sugar Land, TX                  Y            N
# 247  Houston-The Woodlands-Sugar Land, TX                  Y            N
# 248  Houston-The Woodlands-Sugar Land, TX                  Y            N
# 249  Houston-The Woodlands-Sugar Land, TX                  Y            N
# 250  Houston-The Woodlands-Sugar Land, TX                  Y            N
# 251  Houston-The Woodlands-Sugar Land, TX                  Y            N
# 252  Houston-The Woodlands-Sugar Land, TX                  Y            N
# 253  Houston-The Woodlands-Sugar Land, TX                  Y            N
# 254  Houston-The Woodlands-Sugar Land, TX                  Y            N

# %% [markdown]
# What types of agencies in TX are represented in the data?

# %%
agencies["AGENCY_TYPE_NAME"].value_counts()
# Out:
# City                     425
# County                   134
# Other                     32
# University or College     30
# Name: AGENCY_TYPE_NAME, dtype: int64

# %%
# index used to manually sort
agencies["POPULATION_GROUP_DESC"].value_counts()[[1,0,2,4,6,8,13,14,15,3,5,10,9,11,7,12]]
# Out:
# Cities under 2,500                          153
# Cities from 2,500 thru 9,999                164
# Cities from 10,000 thru 24,999               83
# Cities from 25,000 thru 49,999               37
# Cities from 50,000 thru 99,999               21
# Cities from 100,000 thru 249,999             18
# Cities from 250,000 thru 499,999              5
# Cities from 500,000 thru 999,999              3
# Cities 1,000,000 or over                      2
# Non-MSA counties under 10,000                63
# Non-MSA counties from 10,000 thru 24,999     24
# Non-MSA counties from 25,000 thru 99,999      7
# MSA counties under 10,000                    11
# MSA counties from 10,000 thru 24,999          6
# MSA counties from 25,000 thru 99,999         19
# MSA counties 100,000 or over                  5
# Name: POPULATION_GROUP_DESC, dtype: int64

# %%
## index used to manually sort
agencies["PARENT_POP_GROUP_DESC"].value_counts()[[1,0,3,5,6,7,8,2,4]]
# Out:
# Cities under 2,500                  153
# Cities from 2,500 thru 9,999        164
# Cities from 10,000 thru 24,999       83
# Cities from 25,000 thru 49,999       37
# Cities from 50,000 thru 99,999       21
# Cities from 100,000 thru 249,999     18
# All cities 250,000 or over           10
# Non-MSA Counties                     94
# MSA Counties                         41
# Name: PARENT_POP_GROUP_DESC, dtype: int64

# %% [markdown]
# <font color='red'>The number of incidents reported per agency and its relationship to population size is a different story, </font> as I saw with the 2016 data.

# %% [markdown]
# ## Down to business
#
# ### 1. Select intimate partners from victim-offender relationship records
#
# NIBRS_VICTIM_OFFENDER_REL.csv has columns `DATA_YEAR`,`VICTIM_ID`,`OFFENDER_ID`,`RELATIONSHIP_ID`,and `NIBRS_VICTIM_OFFENDER_ID`.
#
# The values for `RELATIONSHIP_ID` are included in NIBRS_RELATIONSHIP.csv (see below)

# %%
#pandas.set_option('display.max_rows', None)
rel_types = pd.read_csv(folder+"NIBRS_RELATIONSHIP.csv")
rel_types
# Out:
#     RELATIONSHIP_ID RELATIONSHIP_CODE  \
# 0                27                XR
# 1                 1                AQ
# 2                 2                BE
# 3                 3                BG
# 4                 4                CF
# 5                 5                CH
# 6                 6                CS
# 7                 7                EE
# 8                 8                ER
# 9                 9                FR
# 10               10                GC
# 11               11                GP
# 12               12                HR
# 13               13                IL
# 14               14                NE
# 15               15                OF
# 16               16                OK
# 17               17                PA
# 18               18                RU
# 19               19                SB
# 20               20                SC
# 21               21                SE
# 22               22                SP
# 23               23                SS
# 24               24                ST
# 25               25                VO
# 26               26                XS
#
#                                     RELATIONSHIP_NAME  RELATIONSHIP_TYPE_ID
# 0   Victim Was Ex-Relationship (Ex-Boyfriend/Girlf...                     2
# 1                             Victim Was Acquaintance                     2
# 2                               Victim Was Babysittee                     2
# 3                     Victim Was Boyfriend/Girlfriend                     2
# 4         Victim Was Child of Boyfriend or Girlfriend                     2
# 5                                    Victim Was Child                     1
# 6                        Victim Was Common-Law Spouse                     1
# 7                                 Victim was Employee                     2
# 8                                 Victim was Employer                     2
# 9                                   Victim Was Friend                     2
# 10                              Victim Was Grandchild                     1
# 11                             Victim Was Grandparent                     1
# 12                            Homosexual Relationship                     2
# 13                                  Victim Was In-law                     1
# 14                                Victim Was Neighbor                     2
# 15                     Victim Was Other Family Member                     1
# 16                         Victim was Otherwise Known                     2
# 17                                  Victim Was Parent                     1
# 18                               Relationship Unknown                     4
# 19                                 Victim Was Sibling                     1
# 20                               Victim Was Stepchild                     1
# 21                                  Victim Was Spouse                     1
# 22                              Victim Was Stepparent                     1
# 23                             Victim Was Stepsibling                     1
# 24                                Victim Was Stranger                     3
# 25                                Victim Was Offender                     4
# 26                               Victim was Ex-Spouse                     2

# %%
drel_types = dict(zip(rel_types['RELATIONSHIP_ID'].to_list(),rel_types['RELATIONSHIP_NAME'].to_list()))
drel_types[21]
# Out:
# 'Victim Was Spouse'

# %% [markdown]
# **Question**: Should I include ex-boyfriends/ex-girlfriends and ex-spouses?
#
# Note: Common-law marriage is a legal framework where a couple may be considered married without having formally registered their relation as a civil or religious marriage.
#
# From the NIBRS User Manual:
#
# *The agency should use the Victim Was Offender category when a participant in the incident was
# a victim and offender in the incident, such as domestic disputes where both husband and wife
# are charged with assault, double murders (two people kill each other), or barroom brawls
# where many participants are arrested*
#
# **Question**: Should I include cases where the victim was marked as both a victim and an offender?
#
#
# For now, I will include
# - victim was spouse (RELATIONSHIP_ID = 21)
# - victim was boyfriend/girlfriend (RELATIONSHIP_ID = 3)
# - victim was common-law spouse (RELATIONSHIP_ID = 6)
# - victim was offender (RELATIONSHIP_ID = 25)
#
# I would like to include *victim was offender* cases because I do not want to exclude cases where the assault perpetrated by the victim failed to be identified as self-defense. Police response in nuanced situations is the very focus of this research project. However, I am not as interested in police response to incidents involving ex-relationships, though in general it would be another interesting factor to consider.
#
# -------------------
#
# 1. Select intimate partners from NIBRS_VICTIM_OFFENDER_REL.csv
# - victim was spouse (RELATIONSHIP_ID = 21)
# - victim was boyfriend/girlfriend (RELATIONSHIP_ID = 3)
# - victim was common-law spouse (RELATIONSHIP_ID = 6)
# - victim was offender (RELATIONSHIP_ID = 25)

# %%
vict = pd.read_csv(folder+"NIBRS_VICTIM_OFFENDER_REL.csv")
vict[:10]
# Out:
#    DATA_YEAR  VICTIM_ID  OFFENDER_ID  RELATIONSHIP_ID  \
# 0       2019  126809311    131452179               24
# 1       2019  126809311    131452177               24
# 2       2019  126813479    131452178               24
# 3       2019  126805732    131452179               24
# 4       2019  126813481    131452177               24
# 5       2019  126805729    131452178               24
# 6       2019  126805729    131452177               24
# 7       2019  126809311    131452178               24
# 8       2019  126813479    131452177               24
# 9       2019  126813482    131455173                1
#
#    NIBRS_VICTIM_OFFENDER_ID
# 0                  39423392
# 1                  39428145
# 2                  39428146
# 3                  39423399
# 4                  39432538
# 5                  39428142
# 6                  39432536
# 7                  39423391
# 8                  39432537
# 9                  39432541

# %%
IPvict = vict.loc[(vict['RELATIONSHIP_ID']==21) | #spouse
                    (vict['RELATIONSHIP_ID']==3) | #boyfriend/girlfriend
                    (vict['RELATIONSHIP_ID']==6) | #common-law spouse
                    (vict['RELATIONSHIP_ID']==25)] #victim was offender

# %%
print("total no. of victim-offender relationship records in TX: ",len(vict))
print("no. of intimate partner relationship records (including mutual offenses) in TX: ", len(IPvict), "(%.2f percent)"%(len(IPvict)/len(vict)*100))
# Out:
# total no. of victim-offender relationship records in TX:  353070
# no. of intimate partner relationship records (including mutual offenses) in TX:  78519 (22.24 percent)

# %%
IPvict_counts = IPvict.replace({'RELATIONSHIP_ID':drel_types}, inplace = False)['RELATIONSHIP_ID'].value_counts()
print(IPvict_counts)
# Out:
# Victim Was Boyfriend/Girlfriend    42109
# Victim Was Spouse                  19824
# Victim Was Offender                10113
# Victim Was Common-Law Spouse        6473
# Name: RELATIONSHIP_ID, dtype: int64

# %%
fig, ax  = plt.subplots(figsize = (13,8))
names = ["Victim was \n Boyfriend/Girfriend","Victim was \n Spouse", "Victim was \n Offender", "Victim was \n Common-Law Spouse" ]
ax.bar(names, IPvict_counts, color = (0.5,0.3,0.5))
ax.set_ylabel("Counts", fontsize = 15, labelpad = 15)
ax.tick_params('both', labelsize =15)

# %% [markdown]
# ### 2. Connect victims to offenses
# - NIBRS_VICTIM_OFFENDER_REL.csv contains `VICTIM_ID`
# - NIBRS_VICTIM_OFFENSE contains both `VICTIM_ID` and `OFFENSE_ID`
# - retain `OFFENDER_ID` from NIBRS_VICTIM_OFFENDER_REL.csv so I can get information on offender later

# %% [markdown]
# I could first select offenses of interest and then join with the IP victim records, OR I could join the IP victim records with all offenses and see what types of offenses are listed. I will do the latter in order not to overlook any prominent offense category.

# %%
offense_types = pd.read_csv(folder+"NIBRS_OFFENSE_TYPE.csv")
offense_types
# Out:
#     OFFENSE_TYPE_ID OFFENSE_CODE                                 OFFENSE_NAME  \
# 0                58          23*                                Not Specified
# 1                 1          09C                         Justifiable Homicide
# 2                 2          26A      False Pretenses/Swindle/Confidence Game
# 3                 3          36B                               Statutory Rape
# 4                 4          11C                Sexual Assault With An Object
# 5                 5          290     Destruction/Damage/Vandalism of Property
# 6                 6          90F                  Family Offenses, Nonviolent
# 7                 7          23G  Theft of Motor Vehicle Parts or Accessories
# 8                 8          370                 Pornography/Obscene Material
# 9                 9          39D                             Sports Tampering
# 10               11          250                       Counterfeiting/Forgery
# 11               12          26D                                Welfare Fraud
# 12               13          23A                               Pocket-picking
# 13               14          23F                     Theft From Motor Vehicle
# 14               15          40B          Assisting or Promoting Prostitution
# 15               16          35A                     Drug/Narcotic Violations
# 16               17          26E                                   Wire Fraud
# 17               18          23B                              Purse-snatching
# 18               19          90I                                      Runaway
# 19               20          200                                        Arson
# 20               21          240                          Motor Vehicle Theft
# 21               22          90E                                  Drunkenness
# 22               23          23C                                  Shoplifting
# 23               24          39B       Operating/Promoting/Assisting Gambling
# 24               25          90A                                   Bad Checks
# 25               26          210                          Extortion/Blackmail
# 26               27          13A                           Aggravated Assault
# 27               28          280                     Stolen Property Offenses
# 28               29          100                         Kidnapping/Abduction
# 29               30          40A                                 Prostitution
# 30               31          39A                             Betting/Wagering
# 31               32          09A         Murder and Nonnegligent Manslaughter
# 32               33          90H                                  Peeping Tom
# 33               34          90J                    Trespass of Real Property
# 34               35          35B                    Drug Equipment Violations
# 35               37          270                                 Embezzlement
# 36               38          09B                       Negligent Manslaughter
# 37               39          520                        Weapon Law Violations
# 38               40          120                                      Robbery
# 39               41          26B   Credit Card/Automated Teller Machine Fraud
# 40               42          90B         Curfew/Loitering/Vagrancy Violations
# 41               43          11B                                       Sodomy
# 42               44          13C                                 Intimidation
# 43               45          23H                            All Other Larceny
# 44               47          23D                          Theft From Building
# 45               49          220                 Burglary/Breaking & Entering
# 46               52          90G                        Liquor Law Violations
# 47               53          90C                           Disorderly Conduct
# 48               54          39C                 Gambling Equipment Violation
# 49               55          36A                                       Incest
# 50               57          510                                      Bribery
# 51               59          64A       Human Trafficking, Commercial Sex Acts
# 52               60          64B     Human Trafficking, Involuntary Servitude
# 53               63          26F                               Identity Theft
# 54               64          26G                    Hacking/Computer Invasion
# 55               62          720                               Animal Cruelty
# 56               65          90K                            Failure to Appear
# 57               66          90L                  Federal Resource Violations
# 58               67          90M                                      Perjury
# 59               69          101                                      Treason
# 60               70          103                                    Espionage
# 61               71          30A         Illegal Entry into the United States
# 62               72          30B                            False Citizenship
# 63               73          30C                             Smuggling Aliens
# 64               74          30D                   Re-entry after Deportation
# 65               75          360        Failure to Register as a Sex Offender
# 66               76          49A     Harboring Escapee/Concealing from Arrest
# 67               77          49B                  Flight to Avoid Prosecution
# 68               78          49C                  Flight to Avoid Deportation
# 69               79          521    Violation of National Firearm Act of 1934
# 70               80          522                  Weapons of Mass Destruction
# 71               81          526                         Explosives Violation
# 72               82          58A                            Import Violations
# 73               83          58B                            Export Violations
# 74               84          61A                      Federal Liquor Offenses
# 75               85          61B                     Federal Tobacco Offenses
# 76               86          620                         Wildlife Trafficking
# 77               46          26C                                Impersonation
# 78               51          13B                               Simple Assault
# 79               56          11D                                     Fondling
# 80               61          40C                      Purchasing Prostitution
# 81               68          26H                             Money Laundering
# 82               36          11A                                         Rape
# 83               50          23E   Theft From Coin-Operated Machine or Device
# 84               10          90D                  Driving Under the Influence
# 85               48          90Z                           All Other Offenses
#
#    CRIME_AGAINST CT_FLAG HC_FLAG  HC_CODE  \
# 0       Property       N       Y      6.0
# 1         Person       N       N      NaN
# 2       Property       Y       Y      NaN
# 3         Person       N       Y      NaN
# 4         Person       N       Y      2.0
# 5       Property       N       Y     11.0
# 6         Person       N       N      NaN
# 7       Property       N       N      NaN
# 8        Society       N       Y      NaN
# 9        Society       N       Y      NaN
# 10      Property       N       Y      NaN
# 11      Property       N       Y      NaN
# 12      Property       N       N      NaN
# 13      Property       Y       N      NaN
# 14       Society       N       Y      NaN
# 15       Society       N       Y      NaN
# 16      Property       Y       Y      NaN
# 17      Property       N       N      NaN
# 18   Not a Crime       N       N      NaN
# 19      Property       N       Y      8.0
# 20      Property       Y       Y      7.0
# 21       Society       N       N      NaN
# 22      Property       N       N      NaN
# 23       Society       N       Y      NaN
# 24      Property       N       N      NaN
# 25      Property       Y       Y      NaN
# 26        Person       N       Y      4.0
# 27      Property       N       Y      NaN
# 28        Person       N       Y      NaN
# 29       Society       N       Y      NaN
# 30       Society       N       Y      NaN
# 31        Person       N       Y      1.0
# 32        Person       N       N      NaN
# 33       Society       N       N      NaN
# 34       Society       N       Y      NaN
# 35      Property       Y       Y      NaN
# 36        Person       N       Y      NaN
# 37       Society       N       Y      NaN
# 38      Property       Y       Y      3.0
# 39      Property       Y       Y      NaN
# 40       Society       N       N      NaN
# 41        Person       N       Y      2.0
# 42        Person       N       Y     10.0
# 43      Property       Y       N      NaN
# 44      Property       Y       N      NaN
# 45      Property       Y       Y      5.0
# 46       Society       N       N      NaN
# 47       Society       N       N      NaN
# 48       Society       N       Y      NaN
# 49        Person       N       Y      NaN
# 50      Property       Y       Y      NaN
# 51        Person       N       Y     12.0
# 52        Person       N       Y     13.0
# 53      Property       Y       Y      NaN
# 54      Property       Y       Y      NaN
# 55       Society       N       N      NaN
# 56       Society       N       N      NaN
# 57       Society       N       N      NaN
# 58       Society       N       N      NaN
# 59       Society       N       N      NaN
# 60       Society       N       N      NaN
# 61       Society       N       N      NaN
# 62       Society       N       N      NaN
# 63       Society       N       N      NaN
# 64       Society       N       N      NaN
# 65       Society       N       N      NaN
# 66       Society       N       N      NaN
# 67       Society       N       N      NaN
# 68       Society       N       N      NaN
# 69       Society       N       N      NaN
# 70       Society       N       N      NaN
# 71       Society       N       N      NaN
# 72       Society       N       N      NaN
# 73       Society       N       N      NaN
# 74       Society       N       N      NaN
# 75       Society       N       N      NaN
# 76       Society       N       N      NaN
# 77      Property       Y       Y      NaN
# 78        Person       N       Y      9.0
# 79        Person       N       Y      2.0
# 80       Society       N       Y      NaN
# 81       Society       N       N      NaN
# 82        Person       N       Y      2.0
# 83      Property       N       N      NaN
# 84       Society       N       N      NaN
# 85       Society       N       N      NaN
#
#                        OFFENSE_CATEGORY_NAME OFFENSE_GROUP
# 0                     Larceny/Theft Offenses             A
# 1                          Homicide Offenses             A
# 2                             Fraud Offenses             A
# 3                 Sex Offenses, Non-forcible             A
# 4                               Sex Offenses             A
# 5   Destruction/Damage/Vandalism of Property             A
# 6                Family Offenses, Nonviolent             B
# 7                     Larceny/Theft Offenses             A
# 8               Pornography/Obscene Material             A
# 9                          Gambling Offenses             A
# 10                    Counterfeiting/Forgery             A
# 11                            Fraud Offenses             A
# 12                    Larceny/Theft Offenses             A
# 13                    Larceny/Theft Offenses             A
# 14                     Prostitution Offenses             A
# 15                    Drug/Narcotic Offenses             A
# 16                            Fraud Offenses             A
# 17                    Larceny/Theft Offenses             A
# 18                            Other Offenses           NaN
# 19                                     Arson             A
# 20                       Motor Vehicle Theft             A
# 21                               Drunkenness             B
# 22                    Larceny/Theft Offenses             A
# 23                         Gambling Offenses             A
# 24                                Bad Checks             B
# 25                       Extortion/Blackmail             A
# 26                          Assault Offenses             A
# 27                  Stolen Property Offenses             A
# 28                      Kidnapping/Abduction             A
# 29                     Prostitution Offenses             A
# 30                         Gambling Offenses             A
# 31                         Homicide Offenses             A
# 32                               Peeping Tom             B
# 33                 Trespass of Real Property             B
# 34                    Drug/Narcotic Offenses             A
# 35                              Embezzlement             A
# 36                         Homicide Offenses             A
# 37                     Weapon Law Violations             A
# 38                                   Robbery             A
# 39                            Fraud Offenses             A
# 40      Curfew/Loitering/Vagrancy Violations             B
# 41                              Sex Offenses             A
# 42                          Assault Offenses             A
# 43                    Larceny/Theft Offenses             A
# 44                    Larceny/Theft Offenses             A
# 45              Burglary/Breaking & Entering             A
# 46                     Liquor Law Violations             B
# 47                        Disorderly Conduct             B
# 48                         Gambling Offenses             A
# 49                Sex Offenses, Non-forcible             A
# 50                                   Bribery             A
# 51                         Human Trafficking             A
# 52                         Human Trafficking             A
# 53                            Fraud Offenses             A
# 54                            Fraud Offenses             A
# 55                            Animal Cruelty             A
# 56                            Other Offenses             B
# 57                            Other Offenses             B
# 58                            Other Offenses             B
# 59                            Other Offenses             A
# 60                            Other Offenses             A
# 61                            Other Offenses             A
# 62                            Other Offenses             A
# 63                            Other Offenses             A
# 64                            Other Offenses             A
# 65                            Other Offenses             A
# 66                            Other Offenses             A
# 67                            Other Offenses             A
# 68                            Other Offenses             A
# 69                            Other Offenses             A
# 70                            Other Offenses             A
# 71                            Other Offenses             A
# 72                            Other Offenses             A
# 73                            Other Offenses             A
# 74                            Other Offenses             A
# 75                            Other Offenses             A
# 76                            Other Offenses             A
# 77                            Fraud Offenses             A
# 78                          Assault Offenses             A
# 79                              Sex Offenses             A
# 80                     Prostitution Offenses             A
# 81                            Other Offenses             A
# 82                              Sex Offenses             A
# 83                    Larceny/Theft Offenses             A
# 84               Driving Under the Influence             B
# 85                        All Other Offenses             B

# %%
doffense_types = dict(zip(offense_types['OFFENSE_TYPE_ID'].to_list(),offense_types['OFFENSE_NAME'].to_list()))
doffense_types[2]
# Out:
# 'False Pretenses/Swindle/Confidence Game'

# %% [markdown]
# See Table 1 in "HON 4355 - Project Update" for selection of UCR offense codes. It may need to be updated as appropriate, e.g.
#
# From [NIBRS Offense Definitions](https://ucr.fbi.gov/nibrs/2012/resources/nibrs-offense-definitions):
#
# **Family Offenses, Nonviolent** — Unlawful, nonviolent acts by a family member (or legal guardian)
# that threaten the physical, mental, or economic well-being or morals of another family member
# and that are not classifiable as other offenses, such as Assault, Incest, Statutory Rape, etc.

# %%
NIBRS_victim_offense = pd.read_csv(folder+"NIBRS_VICTIM_OFFENSE.csv")

# %% [markdown]
# From the README:
#
# This table maps victims to offenses and should be used to get all
# victims of a specific offense associated with an incident. Do not
# simply assume that all offenses associated with an incident apply to all victims.
#
# indicates that multiple victims may be tied to a specific offense, so in this case `OFFENSE_ID` is assumed to be the unique identifier and this suggests a *many-to-one* join. However, since it is possible a single victim in an incident may be a victim of multiple offenses, a *many-to-many* join might be appropriate. It depends on whether a single victim in an incident is assigned a unique `VICTIM_ID` for each offense perpetrated against them, which I can't find a clear answer for.
#
# Either way, I can use `how = 'right'` to ensure that each victim in my list of IP victim-offender relationships is matched with an offense. I tried it both ways and it doesn't matter whether `how = 'inner'` or `how = 'right'` is used.

# %%
vict_offense = pd.merge(left = NIBRS_victim_offense, 
                        right = IPvict,
                        on = ['VICTIM_ID', 'DATA_YEAR'],
                        how = 'right',
)

# %%
len(vict_offense)
# Out:
# 82656

# %%
vict_offense[0:10]
# Out:
#    DATA_YEAR  VICTIM_ID  OFFENSE_ID  OFFENDER_ID  RELATIONSHIP_ID  \
# 0       2019  124513092   137997696    127984921                3
# 1       2019  124513130   137997730    127996409                3
# 2       2019  124513186   137997791    127996472                3
# 3       2019  124502140   137997807    127996490                3
# 4       2019  124513218   137997823    127999960               21
# 5       2019  124509192   137994053    127996540               21
# 6       2019  127868725   141746758    132658000                3
# 7       2019  124513276   137997889    127996581                3
# 8       2019  127864872   141746046    132665214                3
# 9       2019  124513288   137997899    127996592                3
#
#    NIBRS_VICTIM_OFFENDER_ID
# 0                  38503094
# 1                  38506742
# 2                  38506757
# 3                  38503109
# 4                  38506775
# 5                  38499341
# 6                  39889891
# 7                  38506797
# 8                  39895085
# 9                  38506803

# %%
print("no. of intimate partner relationship records (including mutual offenses) in TX: ", len(IPvict))
print("no. of offense records associated with intimate partner relationship between victim-offender: ",len(vict_offense))
# Out:
# no. of intimate partner relationship records (including mutual offenses) in TX:  78519
# no. of offense records associated with intimate partner relationship between victim-offender:  82656

# %% [markdown]
# This shows that the join is not one-to-one (i.e. more offense records that victim-offender relationship records). Let's explore:

# %%
print(len(vict_offense['VICTIM_ID'].unique()))
print(len(vict_offense['OFFENSE_ID'].unique()))
victids = pd.DataFrame(vict_offense[['VICTIM_ID']].value_counts(), columns = ['count'])
# Out:
# 74567
# 73457

# %%
max(victids['count'])
# Out:
# 6

# %%
plt.hist(victids, bins = [1,2,3,4,5,6])
# Out:
# (array([6.6892e+04, 7.3600e+03, 2.2000e+02, 9.3000e+01, 2.0000e+00]),
#  array([1, 2, 3, 4, 5, 6]),
#  <BarContainer object of 5 artists>)

# %%
print(len(victids.loc[victids['count']>1]))
# Out:
# 7675

# %%
# now look at unique instances of a victim_id and an offense_id
victoffids = pd.DataFrame(vict_offense[['VICTIM_ID', 'OFFENSE_ID']].value_counts(), columns = ['count'])

# %%
print(len(victoffids))
print(len(victoffids.loc[victoffids['count']>1]))
# Out:
# 78612
# 4036

# %%
# now look at unique combination of victim_id, offense_id, and offender_id
allids = pd.DataFrame(vict_offense[['VICTIM_ID', 'OFFENSE_ID','OFFENDER_ID']].value_counts(), columns = ['count'])
len(allids)
# Out:
# 82656

# %% [markdown]
# The vast majority of victims are tied to only one offense, but there are 7675 victim ids out of the 74567 victim ids that appear more than once. The most number of times that a victim id appears in the victim-offense dataset is six. The large majority of victim_ids that appear more than once appear twice (i.e. if victims are tied to multiple offenses it is most likely they are tied to two offenses).
#
# I believe the rest of the discrepancy is covered by victims tied to more than one offender, since the number of unique combinations of victim, offender, and offense IDs is equal to the number of instances in the combined data set. Note `OFFENDER_ID` appears in NIBRS_VICTIM_OFFENDER_REL.csv but not in NIBRS_VICTIM_OFFENSE.csv.
#
# **Now let's connect this new dataframe to the NIBRS_OFFENSE.csv using** `OFFENDER_ID`

# %%
NIBRS_offense = pd.read_csv(folder+"NIBRS_offense.csv")

# %%
vict_offns = pd.merge(left = NIBRS_offense, 
                     right = victim_offense, 
                     on = 'OFFENSE_ID')
